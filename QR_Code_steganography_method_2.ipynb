# %% [markdown]
# <a href="https://colab.research.google.com/github/Soujanya-27/Dark-Pattern-Detection/blob/main/QR_Code_steganography_method_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qrcode cryptography pyzbar pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.3 MB/s eta 0:00:00
# ...

# %%
import qrcode
from cryptography.fernet import Fernet
import base64
import os

# Generate and save an encryption key (Run this once)
def generate_key():
    key = Fernet.generate_key()
    with open("secret.key", "wb") as key_file:
        key_file.write(key)

# Load the encryption key
def load_key():
    if not os.path.exists("secret.key"):
        generate_key()
    with open("secret.key", "rb") as key_file:
        return key_file.read()

# Encrypt the hidden message
def encrypt_message(secret_message):
    key = load_key()
    cipher = Fernet(key)
    encrypted_msg = cipher.encrypt(secret_message.encode())
    return base64.b64encode(encrypted_msg).decode()  # Encode to make it QR-friendly

# Create a QR code with a website link and encrypted hidden message
def create_encrypted_qr():
    website_url = input("Enter the website URL: ").strip()
    hidden_msg = input("Enter the hidden message: ").strip()

    encrypted_hidden = encrypt_message(hidden_msg)

    # Store encrypted message inside the URL
    full_data = f"{website_url}#hidden={encrypted_hidden}"

    qr = qrcode.QRCode(error_correction=qrcode.constants.ERROR_CORRECT_H)
    qr.add_data(full_data)
    qr.make()
    img = qr.make_image(fill="black", back_color="white")

    qr_path = "secure_qr.png"
    img.save(qr_path)

    print(f"✅ QR Code saved as {qr_path}")
    print(f"🔗 Scan it to visit: {website_url}")
    print("🔒 The hidden message is encrypted inside the QR.")

# Run QR Code Creation
create_encrypted_qr()
# Out:
# Enter the website URL: https://colab.research.google.com/drive/1ZqA0dP1gANWrn2mDrN51qmWucBjBxsK6#scrollTo=td9-XmiJNxSP
# Enter the hidden message: hyhyhy
# ✅ QR Code saved as secure_qr.png
# 🔗 Scan it to visit: https://colab.research.google.com/drive/1ZqA0dP1gANWrn2mDrN51qmWucBjBxsK6#scrollTo=td9-XmiJNxSP
# 🔒 The hidden message is encrypted inside the QR.

# %%
# !apt-get update
# !apt-get install -y libzbar0
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,605 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,841 kB]
# ...

# %%
# !pip install pyzbar

# %%
from pyzbar.pyzbar import decode
from PIL import Image
import base64

# Decrypt hidden message
def decrypt_message(encrypted_message):
    key = load_key()
    cipher = Fernet(key)
    decrypted_msg = cipher.decrypt(base64.b64decode(encrypted_message)).decode()
    return decrypted_msg

# Extract hidden message from QR
def extract_encrypted_qr():
    qr_image_path = input("Enter the path of the QR code image: ").strip()

    try:
        qr_img = Image.open(qr_image_path)
        decoded_data = decode(qr_img)

        if not decoded_data:
            print("❌ No QR code found in the image.")
            return

        decoded_text = decoded_data[0].data.decode()

        # Extract hidden part from the URL
        if "#hidden=" in decoded_text:
            website_link, hidden_encoded = decoded_text.split("#hidden=", 1)
            try:
                hidden_message = decrypt_message(hidden_encoded)
                print(f"\n🔗 Website: {website_link}")
                print(f"🔒 Hidden Message: {hidden_message}")
            except Exception:
                print("❌ Decryption Failed: Invalid Key!")
        else:
            print(f"\n🔗 Website: {decoded_text}")
            print("❌ No hidden data found.")

    except FileNotFoundError:
        print("❌ File not found. Please enter a valid QR code image path.")

# Run QR Code Extraction
extract_encrypted_qr()
# Out:
# Enter the path of the QR code image: /content/secure_qr.png
#
# 🔗 Website: https://www.google.com/search?gs_ssp=eJzj4tTP1TcwTDOprDRg9BIrKC0qyElVSMnMyy9OLC1SSEosykutBADIagwb&q=purple+dinosaur+barney&rlz=1C1VDKB_enIN1087IN1088&oq=&gs_lcrp=EgZjaHJvbWUqCQgCEC4YJxjqAjIJCAAQIxgnGOoCMgkIARAjGCcY6gIyCQgCEC4YJxjqAjIJCAMQIxgnGOoCMgkIBBAjGCcY6gIyCQgFECMYJxjqAjIJCAYQIxgnGOoCMgkIBxBFGDsYwgPSAQ0yNTcwODk4ODFqMGo3qAIIsAIB8QXJO8zV3vgXog&sourceid=chrome&ie=UTF-8
# 🔒 Hidden Message: hyhyh

# %%
# !apt-get install libzbar0
# !pip install pyzbar
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts imagemagick-6-common
#   libdjvulibre-text libdjvulibre21 libfftw3-double3 libgs9 libgs9-common libidn12 libijs-0.35
#   libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra
#   libmagickwand-6.q16-6 libv4l-0 libv4lconvert0 libwmflite-0.2-7 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x libfftw3-bin
#   libfftw3-dev inkscape poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts imagemagick-6-common
# ...
